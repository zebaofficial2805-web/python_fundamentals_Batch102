# %%
contribution with string datatype :

# %%
introduction to f strings:

# %%
firstname = 'chakri'

lastname = 'shiva'

# %%
# req : i want to get fullname....?

# %%
# general syntax of f strings :

# %%
message = f"you can give your custom message {place_holder_1} {place_holder_2}......{place_holder_n}"

# %%
firstname = 'chakri'

lastname = 'shiva'

fullname = f"{firstname} {lastname}"

print(fullname)
# Out:
# chakri shiva

# %%
message = f"keep up the good work, {fullname.title()}"

print(fullname)
# Out:
# chakri shiva

# %%
message = f"keep up the good work, {fullname.title()}"

print(message)
# Out:
# keep up the good work, Chakri Shiva

# %%
# req : need to rework on it

# %%
adding whitespaces to strings :

# %%
print("Favourite_programming_Language:PythonJavaJavascriptC++")
# Out:
# Favourite_programming_Language:PythonJavaJavascriptC++

# %%
print("Favourite_programming_Language:\nPython\nJava\nJavascript\nC++")
# Out:
# Favourite_programming_Language:
# Python
# Java
# Javascript
# C++

# %%
# \n ----> is called a new line delimiter

# %%
print("Favourite_programming_Language:\n\tPython\n\tJava\n\tJavascript\n\tC++")
# Out:
# Favourite_programming_Language:
# 	Python
# 	Java
# 	Javascript
# 	C++

# %%
\t is called as a tab delimiter(4 space at once)

# %%
removing whitespaces from strings :

# %%
name = 'python'

print(name)
# Out:
# python

# %%
name2 = '  python'

print(name2)
# Out:
#   python

# %%
name3 = 'python  '

print(name3)
# Out:
# python

# %%
name4 = '  python  '

print(name4)
# Out:
#   python

# %%
name4.strip()
# Out:
# 'python'

# %%
name2.lstrip()
# Out:
# 'python'

# %%
name3.rstrip()
# Out:
# 'python'

# %%
name4.strip()
# Out:
# 'python'

# %%
introduction to numbers

# %%
integers :

# %%
num = 123

# %%
print(num)
# Out:
# 123

# %%
type(num)
# Out:
# int

# %%
floats

# %%
test = 0.1

print(test)
# Out:
# 0.1

# %%
type(test)
# Out:
# float

# %%
Note -1 : python is a case senstive programming language

# %%
Print(test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 Print(test)
#
# NameError: name 'Print' is not defined

# %%
# is used for commenting the code...
