# %%
Introduction of list datatype:

# %%
Defination : A list is a collection of otems declaired in a particular order.

Classification : It is classififed as a mutable datatype

How to define the list --------> [ ]

# %%
students = ['vijay','monika','david','feroz','asma']

print(students)
# Out:
# ['vijay', 'monika', 'david', 'feroz', 'asma']

# %%
print(students)
# Out:
# ['vijay', 'monika', 'david', 'feroz', 'asma']

# %%
type(students)
# Out:
# list

# %%
Introduction of indexing : 0,1,2,3,........n

# %%
1. how to access the elments from the list.

2. how to modify elements from the list.

3. how to delete elements from the list.

# %%
# i want to access vijay name from the above list....?

# %%
print(students[0].title())
# Out:
# Vijay

# %%
# req : in want to appriciate vijay

# %%
print(f"keep it up the good work, {students[0].title()}")
# Out:
# keep it up the good work, Vijay

# %%
print(students[2])
# Out:
# david

# %%
print(students)
# Out:
# ['vijay', 'monika', 'david', 'feroz', 'asma']

# %%
# req : i wnat to add kavitha name in the students list....?

# %%
students.append('kavitha')

# %%
print(students)
# Out:
# ['vijay', 'monika', 'david', 'feroz', 'asma', 'kavitha']

# %%
# sreeja

# %%
students.append('sreeja')

# %%
print(students)
# Out:
# ['vijay', 'monika', 'david', 'feroz', 'asma', 'kavitha', 'sreeja', 'sreeja', 'sreeja']

# %%
# req : i want to add anil in 2nd index....

# %%
students.insert(2,'anil')

# %%
print(students)
# Out:
# ['vijay', 'monika', 'anil', 'david', 'feroz', 'asma', 'kavitha', 'sreeja', 'sreeja', 'sreeja']

# %%
req : i want to replace monika to mohan....

# %%
students[1] = 'Mohan'

# %%
print(students)
# Out:
# ['vijay', 'Mohan', 'anil', 'david', 'feroz', 'asma', 'kavitha', 'sreeja', 'sreeja', 'sreeja']

# %%
# req : i want to delet vijay name from the list.....(Permanent and Temperary)

# %%
del students[0]  # permanent deleting

# %%
print(students)
# Out:
# ['Mohan', 'anil', 'david', 'feroz', 'asma', 'kavitha', 'sreeja', 'sreeja', 'sreeja']

# %%
# req Temperary deleting

# %%
# it will create a carbon copy of the deleted item...

# %%
pop method -----> in general pop will be delete the lat item from the list

# %%
print(students)
# Out:
# ['Mohan', 'anil', 'david', 'feroz', 'asma', 'kavitha', 'sreeja', 'sreeja', 'sreeja']

# %%
x = students.pop()

# %%
print(students)
# Out:
# ['Mohan', 'anil', 'david', 'feroz', 'asma', 'kavitha', 'sreeja', 'sreeja']

# %%
print(x)
# Out:
# sreeja

# %%
what is defferance between delete and pop menthod in the list datatype...?

# %%
and : permanent detele and teperary delete
