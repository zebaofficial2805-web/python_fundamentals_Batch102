# %%
Introduction of python programming

# %%
Introduction of variables in python

# %%
a = 2
b = 3

# %%
c = a+b

print(c)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 c = a+b
#       3 print(c)
#
# NameError: name 'a' is not defined

# %%
Rules for declaring the variables :

# %%
Rule No -1 : No Nmaespaces for declaring the variables

# %%
first name = 'zeba'

print(first name)
# Out:
#   Cell In[7], line 1
#     first name = 'zeba'
#           ^
# SyntaxError: invalid syntax

# %%
firstname = 'Zeba'

print(firstname)
# Out:
# Zeba

# %%
Rule No 2 : A variable name should not start with a number **

# %%
1name = "ravi"

print(1name)
# Out:
#   Cell In[10], line 1
#     1name = "ravi"
#     ^
# SyntaxError: invalid decimal literal

# %%
name1 = "ravi"

print(name1)
# Out:
# ravi

# %%
Rule No 3 : A variable name should not contain any special characters

# %%
@ # $ % & *

# %%
test@ = "navya"

print(test@)
# Out:
#   Cell In[12], line 1
#     test@ = "navya"
#           ^
# SyntaxError: invalid syntax

# %%
test = "navya"

print(test)
# Out:
# navya

# %%
Introduction of Datatupes in python :

1. string ------>str
2. numbers -------> integers (int) and float ( decinals ---0.1,0.2)
3. list --------> list
4. tuples -------> tuple
5. dictionaries -------> dict

# %%
classification of datatypes :

  Broadly datatypes are classified in 2 different catagories

  1. mutable datatype -----> which we can be able to edit / alter -----> flexible in Nature
  2. immutabale datatype ------> which we cannot be able to edit / alter -----> fixed in Nature

# %%
1). string =====>

Defination : A string is nothing but a series of characters declared in quotes.

classification  : It is classified as immutable datatype

how do yoy define the string -------?

1. single quotes

2. double quotes

# %%
name = 'asma' # single quotes
print(name)
# Out:
# asma

# %%
name2 = "asma" # double quotes
print(name)
# Out:
# asma

# %%
introduction of string methods :

# %%
type(name)
# Out:
# str

# %%
type(name2)
# Out:
# str

# %%
fullname = 'zeba anjum'

print(fullname)
# Out:
# zeba anjum

# %%
print(fullname.title())
# Out:
# Zeba Anjum

# %%
# req : i want to get the name in capital letters

# %%
print(fullname.upper())
# Out:
# ZEBA ANJUM

# %%
# req : i want to get the name in small letters

# %%
print(fullname.lower())
# Out:
# zeba anjum

# %%
zen of python ----->

# %%
The Zen of Python, by Tim Peters

Beautiful is better than ugly. 
Explicit is better than implicit. 
Simple is better than complex. 
Complex is better than complicated. 
Flat is better than nested. 
Sparse is better than dense. 
Readability counts. 
Special cases aren't special enough to break the rules.
Although practicality beats purity. 
Errors should never pass silently.
Unless explicitly silenced.
In the face of ambiguity, refuse the temptation to guess.
There should be one and preferably only one-- obvious way to do it. 
Although that way may not be obvious at first unless you're Dutch.
Now is better than never.
Although never is often better than "right" now.
If the implementation is hard to explain, it's a bad idea..
If the implementation is easy to explain, it may be a good idea. 
Namespaces are one honking great idea let's do more of those!
